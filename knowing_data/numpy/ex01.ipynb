# %%
import numpy as np

# %%
# Out:
# array([1, 2, 3])

# %%
np.zeros([2,4], dtype=float)
# Out:
# array([[0., 0., 0., 0.],
#        [0., 0., 0., 0.]])

# %%
np.ones([2,4], dtype=int)
# Out:
# array([[1, 1, 1, 1],
#        [1, 1, 1, 1]])

# %%
np.arange(0,10,2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.full([3,5], 6.9)
# Out:
# array([[6.9, 6.9, 6.9, 6.9, 6.9],
#        [6.9, 6.9, 6.9, 6.9, 6.9],
#        [6.9, 6.9, 6.9, 6.9, 6.9]])

# %%
np.random.random((4,4),)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 np.random.random((4,4), dtype = int)
#
# File numpy/random/mtrand.pyx:443, in numpy.random.mtrand.RandomState.random()
#
# TypeError: random() got an unexpected keyword argument 'dtype'

# %%
np.random.normal(0,1)

# %% [markdown]
# array indexing & slicing1

# %%
x1= np.random.randint(20, size=6)
# Out:
# array([ 9, 11, 18,  4,  1,  3], dtype=int32)
